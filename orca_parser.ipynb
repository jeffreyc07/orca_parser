# %%
import os
import re
import sys
import numpy
import pandas as pd
import matplotlib.pyplot as plt

# %%
filename = "S_mult1.out"

# %%
with open(filename,"r") as infile:
    
    section = "none"
    for line in infile:
        # Defining the necessary lines
        if line.strip() == "SPIN ORBIT CORRECTED ABSORPTION SPECTRUM VIA TRANSITION ELECTRIC DIPOLE MOMENTS":
            section = "soc absorption spectrum"
        if line.strip() == "TOTAL RUN TIME":
            section = "time"
        # Defining the parser for each section
        if section == "soc" and re.match("^[ 0-9.]*$", line) is not None:
            transition = re.match("\s*(\d*)\s*(\d*)\s*(\d*\.\d*)\s*(\d*\.\d*)\s*(\d*\.\d*)\s*(\d\.\d*)\s*(\d*\.\d*)\s*(\d\.\d*)\s*(\d*\.\d*)",line)
        if state == "time" and re.match("(\d)*\s\w*\s(\d*)\s\w*\s(\d*)\s\w*\s(\d*)\s\w*\s(\d*)\s\w*", line) is not None:
            runtime = re.match("(\d)*\s\w*\s(\d*)\s\w*\s(\d*)\s\w*\s(\d*)\s\w*\s(\d*)\s\w*", line)

# %%
transition
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\OneDrive - University of Toronto\Github\orca_parser\orca_parser\orca_parser.ipynb Cell 4 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/OneDrive%20-%20University%20of%20Toronto/Github/orca_parser/orca_parser/orca_parser.ipynb#ch0000003?line=0'>1</a> transition
#
# NameError: name 'transition' is not defined
